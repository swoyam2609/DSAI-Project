# %%
import pandas as pd

# %%
df = pd.read_csv("../Dataset/time_series_covid19_confirmed_global.csv")

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  \
# 0        0        0        0        0  ...   209322  209340  209358  209362
# 1        0        0        0        0  ...   334391  334408  334408  334427
# 2        0        0        0        0  ...   271441  271448  271463  271469
# 3        0        0        0        0  ...    47866   47875   47875   47875
# 4        0        0        0        0  ...   105255  105277  105277  105277
#
#    3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# ...

# %%
df.drop('Province/State', axis=1, inplace=True)

# %%
df.head(100)
# Out:
#          Country/Region       Lat       Long  1/22/20  1/23/20  1/24/20  \
# 0           Afghanistan  33.93911  67.709953        0        0        0
# 1               Albania  41.15330  20.168300        0        0        0
# 2               Algeria  28.03390   1.659600        0        0        0
# 3               Andorra  42.50630   1.521800        0        0        0
# 4                Angola -11.20270  17.873900        0        0        0
# ..                  ...       ...        ...      ...      ...      ...
# 95  Congo (Brazzaville)  -0.22800  15.827700        0        0        0
# 96     Congo (Kinshasa)  -4.03830  21.758700        0        0        0
# 97           Costa Rica   9.74890 -83.753400        0        0        0
# 98        Cote d'Ivoire   7.54000  -5.547100        0        0        0
# 99              Croatia  45.10000  15.200000        0        0        0
#
#     1/25/20  1/26/20  1/27/20  1/28/20  ...  2/28/23   3/1/23   3/2/23  \
# ...

# %%
df.shape
# Out:
# (289, 1146)

# %%
uniqueCountries = df['Country/Region'].unique()
print(len(uniqueCountries))
# Out:
# 201

# %%
df2 = df.groupby('Country/Region').sum().reset_index()
df2.drop(['Lat', 'Long'], axis=1, inplace=True)
df2.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
# 3        Andorra        0        0        0        0        0        0
# 4         Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  3/4/23  \
# 0        0        0        0  ...   209322  209340  209358  209362  209369
# 1        0        0        0  ...   334391  334408  334408  334427  334427
# 2        0        0        0  ...   271441  271448  271463  271469  271469
# 3        0        0        0  ...    47866   47875   47875   47875   47875
# 4        0        0        0  ...   105255  105277  105277  105277  105277
#
#    3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0  209390  209406  209436  209451  209451
# ...

# %%
df2.shape
# Out:
# (201, 1144)

# %%
import matplotlib.pyplot as plt

# %%
df2.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
# 3        Andorra        0        0        0        0        0        0
# 4         Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  3/4/23  \
# 0        0        0        0  ...   209322  209340  209358  209362  209369
# 1        0        0        0  ...   334391  334408  334408  334427  334427
# 2        0        0        0  ...   271441  271448  271463  271469  271469
# 3        0        0        0  ...    47866   47875   47875   47875   47875
# 4        0        0        0  ...   105255  105277  105277  105277  105277
#
#    3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0  209390  209406  209436  209451  209451
# ...

# %%
df2.rename(columns={'Country/Region': 'Country'}, inplace=True)
df2.head()
# Out:
#        Country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# 0  Afghanistan        0        0        0        0        0        0        0
# 1      Albania        0        0        0        0        0        0        0
# 2      Algeria        0        0        0        0        0        0        0
# 3      Andorra        0        0        0        0        0        0        0
# 4       Angola        0        0        0        0        0        0        0
#
#    1/29/20  1/30/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  3/4/23  3/5/23  \
# 0        0        0  ...   209322  209340  209358  209362  209369  209390
# 1        0        0  ...   334391  334408  334408  334427  334427  334427
# 2        0        0  ...   271441  271448  271463  271469  271469  271477
# 3        0        0  ...    47866   47875   47875   47875   47875   47875
# 4        0        0  ...   105255  105277  105277  105277  105277  105277
#
#    3/6/23  3/7/23  3/8/23  3/9/23
# ...

# %%
df2Transposed = df2.transpose()
df2Transposed.reset_index(inplace=True)
df2Transposed.head()
# Out:
#      index            0        1        2        3       4           5  \
# 0  Country  Afghanistan  Albania  Algeria  Andorra  Angola  Antarctica
# 1  1/22/20            0        0        0        0       0           0
# 2  1/23/20            0        0        0        0       0           0
# 3  1/24/20            0        0        0        0       0           0
# 4  1/25/20            0        0        0        0       0           0
#
#                      6          7        8  ...      191         192      193  \
# 0  Antigua and Barbuda  Argentina  Armenia  ...  Uruguay  Uzbekistan  Vanuatu
# 1                    0          0        0  ...        0           0        0
# 2                    0          0        0  ...        0           0        0
# 3                    0          0        0  ...        0           0        0
# 4                    0          0        0  ...        0           0        0
#
# ...

# %%
df2Transposed =df2Transposed.set_axis(df2Transposed.iloc[0], axis=1)
df2Transposed =df2Transposed[1:]

# %%
df2Transposed.head()
# Out:
# 0  Country Afghanistan Albania Algeria Andorra Angola Antarctica  \
# 1  1/22/20           0       0       0       0      0          0
# 2  1/23/20           0       0       0       0      0          0
# 3  1/24/20           0       0       0       0      0          0
# 4  1/25/20           0       0       0       0      0          0
# 5  1/26/20           0       0       0       0      0          0
#
# 0 Antigua and Barbuda Argentina Armenia  ... Uruguay Uzbekistan Vanuatu  \
# 1                   0         0       0  ...       0          0       0
# 2                   0         0       0  ...       0          0       0
# 3                   0         0       0  ...       0          0       0
# 4                   0         0       0  ...       0          0       0
# 5                   0         0       0  ...       0          0       0
#
# 0 Venezuela Vietnam West Bank and Gaza Winter Olympics 2022 Yemen Zambia  \
# ...

# %%
df2Transposed['Country']=pd.to_datetime(df2Transposed['Country'])
# Out:
# /var/folders/48/sjhcgn5d03dg2p_w7g0zzsr40000gn/T/ipykernel_15505/3376081690.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df2Transposed['Country']=pd.to_datetime(df2Transposed['Country'])

# %%
df2Transposed.head()
# Out:
# 0    Country Afghanistan Albania Algeria Andorra Angola Antarctica  \
# 1 2020-01-22           0       0       0       0      0          0
# 2 2020-01-23           0       0       0       0      0          0
# 3 2020-01-24           0       0       0       0      0          0
# 4 2020-01-25           0       0       0       0      0          0
# 5 2020-01-26           0       0       0       0      0          0
#
# 0 Antigua and Barbuda Argentina Armenia  ... Uruguay Uzbekistan Vanuatu  \
# 1                   0         0       0  ...       0          0       0
# 2                   0         0       0  ...       0          0       0
# 3                   0         0       0  ...       0          0       0
# 4                   0         0       0  ...       0          0       0
# 5                   0         0       0  ...       0          0       0
#
# 0 Venezuela Vietnam West Bank and Gaza Winter Olympics 2022 Yemen Zambia  \
# ...

# %%
df2Transposed=df2Transposed.transpose()

# %%
df2Transposed.head()
# Out:
#                             1                    2                    3     \
# 0
# Country      2020-01-22 00:00:00  2020-01-23 00:00:00  2020-01-24 00:00:00
# Afghanistan                    0                    0                    0
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
#
#                             4                    5                    6     \
# 0
# Country      2020-01-25 00:00:00  2020-01-26 00:00:00  2020-01-27 00:00:00
# Afghanistan                    0                    0                    0
# Albania                        0                    0                    0
# Algeria                        0                    0                    0
# Andorra                        0                    0                    0
#
# ...

# %%
df2Transposed =df2Transposed.set_axis(df2Transposed.iloc[0], axis=1)
df2Transposed =df2Transposed[1:]
# Out:
# /Users/swoyamsiddharth/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:7631: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(index_like, name=name, copy=copy)

# %%
df2Transposed.head()
# Out:
# Country     2020-01-22 2020-01-23 2020-01-24 2020-01-25 2020-01-26 2020-01-27  \
# 0
# Afghanistan          0          0          0          0          0          0
# Albania              0          0          0          0          0          0
# Algeria              0          0          0          0          0          0
# Andorra              0          0          0          0          0          0
# Angola               0          0          0          0          0          0
#
# Country     2020-01-28 2020-01-29 2020-01-30 2020-01-31  ... 2023-02-28  \
# 0                                                        ...
# Afghanistan          0          0          0          0  ...     209322
# Albania              0          0          0          0  ...     334391
# Algeria              0          0          0          0  ...     271441
# Andorra              0          0          0          0  ...      47866
# Angola               0          0          0          0  ...     105255
# ...

# %%
df2Transposed.to_csv('country.csv')
