# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Dataset/country_cases.csv')

# %%
df.head()
# Out:
#        Country  22/01/20  23/01/20  24/01/20  25/01/20  26/01/20  27/01/20  \
# 0  Afghanistan         0         0         0         0         0         0
# 1      Albania         0         0         0         0         0         0
# 2      Algeria         0         0         0         0         0         0
# 3      Andorra         0         0         0         0         0         0
# 4       Angola         0         0         0         0         0         0
#
#    28/01/20  29/01/20  30/01/20  ...  28/02/23  01/03/23  02/03/23  03/03/23  \
# 0         0         0         0  ...    209322    209340    209358    209362
# 1         0         0         0  ...    334391    334408    334408    334427
# 2         0         0         0  ...    271441    271448    271463    271469
# 3         0         0         0  ...     47866     47875     47875     47875
# 4         0         0         0  ...    105255    105277    105277    105277
#
# ...

# %%
df=df.transpose()

# %%
df.head()
# Out:
#                   0        1        2        3       4           5    \
# Country   Afghanistan  Albania  Algeria  Andorra  Angola  Antarctica
# 22/01/20            0        0        0        0       0           0
# 23/01/20            0        0        0        0       0           0
# 24/01/20            0        0        0        0       0           0
# 25/01/20            0        0        0        0       0           0
#
#                           6          7        8          9    ...      191  \
# Country   Antigua and Barbuda  Argentina  Armenia  Australia  ...  Uruguay
# 22/01/20                    0          0        0          0  ...        0
# 23/01/20                    0          0        0          0  ...        0
# 24/01/20                    0          0        0          0  ...        0
# 25/01/20                    0          0        0          0  ...        0
#
#                  192      193        194      195                 196  \
# ...

# %%
df =df.set_axis(df.iloc[0], axis=1)
df =df[1:]

# %%
df.head()
# Out:
# Country  Afghanistan Albania Algeria Andorra Angola Antarctica  \
# 22/01/20           0       0       0       0      0          0
# 23/01/20           0       0       0       0      0          0
# 24/01/20           0       0       0       0      0          0
# 25/01/20           0       0       0       0      0          0
# 26/01/20           0       0       0       0      0          0
#
# Country  Antigua and Barbuda Argentina Armenia Australia  ... Uruguay  \
# 22/01/20                   0         0       0         0  ...       0
# 23/01/20                   0         0       0         0  ...       0
# 24/01/20                   0         0       0         0  ...       0
# 25/01/20                   0         0       0         0  ...       0
# 26/01/20                   0         0       0         4  ...       0
#
# Country  Uzbekistan Vanuatu Venezuela Vietnam West Bank and Gaza  \
# 22/01/20          0       0         0       0                  0
# ...

# %%
df = df[['India']]
df.head()
# Out:
# Country  India
# 22/01/20     0
# 23/01/20     0
# 24/01/20     0
# 25/01/20     0
# 26/01/20     0

# %%
df.to_csv("../Dataset/india_cases.csv", index=True, header=True, sep=",", mode="w")

# %%
import matplotlib.pyplot as plt

df.plot(figsize=(20,10))
# Out:
# <Axes: >
