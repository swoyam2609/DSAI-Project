# %%
import pandas as pd

# %%
df = pd.read_csv("../Dataset/country.csv")

# %%
df.head()
# Out:
#        Country  22/01/20  23/01/20  24/01/20  25/01/20  26/01/20  27/01/20  \
# 0  Afghanistan         0         0         0         0         0         0
# 1      Albania         0         0         0         0         0         0
# 2      Algeria         0         0         0         0         0         0
# 3      Andorra         0         0         0         0         0         0
# 4       Angola         0         0         0         0         0         0
#
#    28/01/20  29/01/20  30/01/20  ...  28/02/23  01/03/23  02/03/23  03/03/23  \
# 0         0         0         0  ...    209322    209340    209358    209362
# 1         0         0         0  ...    334391    334408    334408    334427
# 2         0         0         0  ...    271441    271448    271463    271469
# 3         0         0         0  ...     47866     47875     47875     47875
# 4         0         0         0  ...    105255    105277    105277    105277
#
# ...

# %%
for i in df.columns:
    if i=="Country":
        continue
    else:
        df.rename(columns={i: pd.to_datetime(i)}, inplace=True)

# %%
df.head()
# Out:
#        Country  2020-01-22 00:00:00  2020-01-23 00:00:00  2020-01-24 00:00:00  \
# 0  Afghanistan                    0                    0                    0
# 1      Albania                    0                    0                    0
# 2      Algeria                    0                    0                    0
# 3      Andorra                    0                    0                    0
# 4       Angola                    0                    0                    0
#
#    2020-01-25 00:00:00  2020-01-26 00:00:00  2020-01-27 00:00:00  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    2020-01-28 00:00:00  2020-01-29 00:00:00  2020-01-30 00:00:00  ...  \
# ...

# %%
df=df.transpose()

# %%
df.head()
# Out:
#                              0        1        2        3       4    \
# Country              Afghanistan  Albania  Algeria  Andorra  Angola
# 2020-01-22 00:00:00            0        0        0        0       0
# 2020-01-23 00:00:00            0        0        0        0       0
# 2020-01-24 00:00:00            0        0        0        0       0
# 2020-01-25 00:00:00            0        0        0        0       0
#
#                             5                    6          7        8    \
# Country              Antarctica  Antigua and Barbuda  Argentina  Armenia
# 2020-01-22 00:00:00           0                    0          0        0
# 2020-01-23 00:00:00           0                    0          0        0
# 2020-01-24 00:00:00           0                    0          0        0
# 2020-01-25 00:00:00           0                    0          0        0
#
#                            9    ...      191         192      193        194  \
# ...

# %%
df =df.set_axis(df.iloc[0], axis=1)
df =df[1:]

# %%
df.head()
# Out:
# Country             Afghanistan Albania Algeria Andorra Angola Antarctica  \
# 2020-01-22 00:00:00           0       0       0       0      0          0
# 2020-01-23 00:00:00           0       0       0       0      0          0
# 2020-01-24 00:00:00           0       0       0       0      0          0
# 2020-01-25 00:00:00           0       0       0       0      0          0
# 2020-01-26 00:00:00           0       0       0       0      0          0
#
# Country             Antigua and Barbuda Argentina Armenia Australia  ...  \
# 2020-01-22 00:00:00                   0         0       0         0  ...
# 2020-01-23 00:00:00                   0         0       0         0  ...
# 2020-01-24 00:00:00                   0         0       0         0  ...
# 2020-01-25 00:00:00                   0         0       0         0  ...
# 2020-01-26 00:00:00                   0         0       0         4  ...
#
# Country             Uruguay Uzbekistan Vanuatu Venezuela Vietnam  \
# ...

# %%
df.shape
# Out:
# (1143, 201)

# %%
df.rename(columns={"Country": "Date"}, inplace=True)

# %%
df.head()
# Out:
# Country             Afghanistan Albania Algeria Andorra Angola Antarctica  \
# 2020-01-22 00:00:00           0       0       0       0      0          0
# 2020-01-23 00:00:00           0       0       0       0      0          0
# 2020-01-24 00:00:00           0       0       0       0      0          0
# 2020-01-25 00:00:00           0       0       0       0      0          0
# 2020-01-26 00:00:00           0       0       0       0      0          0
#
# Country             Antigua and Barbuda Argentina Armenia Australia  ...  \
# 2020-01-22 00:00:00                   0         0       0         0  ...
# 2020-01-23 00:00:00                   0         0       0         0  ...
# 2020-01-24 00:00:00                   0         0       0         0  ...
# 2020-01-25 00:00:00                   0         0       0         0  ...
# 2020-01-26 00:00:00                   0         0       0         4  ...
#
# Country             Uruguay Uzbekistan Vanuatu Venezuela Vietnam  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
plt.ylim(0,103802702)
for i in df.columns:
    lst = df[i].tolist()
    plt.plot(lst, label=i)
plt.xlabel("Days")
plt.ylabel("No. of cases")
plt.legend()
plt.show()

# %%
for i in df.columns:
    plt.figure(figsize=(4,2))
    plt.ylim(0,103802702)
    lst = df[i].tolist()
    plt.plot(lst, label=i)
    plt.xlabel("Days")
    plt.ylabel("No. of cases")
    plt.legend()
    plt.show()
